# %%
import f90nml
from opentea.noob.asciigraph import nob_asciigraph
nml = f90nml.read('cgem.nml')
nml_dict = nml.todict()
print(nob_asciigraph(nml_dict)) # show output
# Out:
# ┣ switches (OrderedDict)
# ┃  ┣ which_fluxes (list)
# ┃  ┃    ┣ List item #0 (int) : 0
# ┃  ┃    ┣ List item #1 (int) : 0
# ┃  ┃    ┣ List item #2 (int) : 0
# ┃  ┃    ┣ List item #3 (int) : 0
# ┃  ┃    ┣ List item #4 (int) : 0
# ┃  ┃    ┣ List item #5 (int) : 0
# ┃  ┃    ┣ List item #6 (int) : 0
# ┃  ┃    ┗ List item #7 (int) : 0
# ┃  ┣ which_temperature (int) : 1
# ┃  ┣ which_uptake (int) : 1
# ┃  ┣ which_quota (int) : 1
# ┃  ┣ which_irradiance (int) : 1
# ┃  ┣ which_chlac (int) : 1
# ┃  ┣ which_photosynthesis (int) : 2
# ┃  ┗ which_growth (int) : 1
# ┣ optics (OrderedDict)
# ┃  ┣ kw (float) : 0.146
# ┃  ┣ kcdom (float) : 0.001
# ┃  ┣ kspm (float) : 0.029
# ┃  ┣ kchla (float) : 0.024
# ┃  ┣ astar490 (float) : 0.0375
# ┃  ┣ aw490 (float) : 0.015
# ┃  ┣ astaroma (float) : 0.01
# ┃  ┣ astaromz (float) : 0.01
# ┃  ┣ astaromr (float) : 0.01
# ┃  ┣ astarombc (float) : 0.01
# ┃  ┗ parfac (float) : 1.0
# ┣ temperature (OrderedDict)
# ┃  ┣ tref (list)
# ┃  ┃    ┣ List item #0 (int) : 17
# ┃  ┃    ┣ List item #1 (int) : 17
# ┃  ┃    ┣ List item #2 (int) : 17
# ┃  ┃    ┣ List item #3 (int) : 22
# ┃  ┃    ┗ List item #4 (int) : 26
# ┃  ┣ ktg1 (list)
# ┃  ┃    ┣ List item #0 (float) : 0.0035
# ┃  ┃    ┣ List item #1 (float) : 0.0035
# ┃  ┃    ┣ List item #2 (float) : 0.0035
# ┃  ┃    ┣ List item #3 (float) : 0.0035
# ┃  ┃    ┗ List item #4 (float) : 0.0035
# ┃  ┣ ktg2 (list)
# ┃  ┃    ┣ List item #0 (float) : 0.001
# ┃  ┃    ┣ List item #1 (float) : 0.001
# ┃  ┃    ┣ List item #2 (float) : 0.001
# ┃  ┃    ┣ List item #3 (float) : 0.001
# ┃  ┃    ┗ List item #4 (float) : 0.001
# ┃  ┗ ea (list)
# ┃  ┃    ┣ List item #0 (float) : 0.61
# ┃  ┃    ┣ List item #1 (float) : 0.61
# ┃  ┃    ┣ List item #2 (float) : 0.61
# ┃  ┃    ┣ List item #3 (float) : 0.61
# ┃  ┃    ┗ List item #4 (float) : 0.61
# ┣ phytoplankton (OrderedDict)
# ┃  ┣ ediblevector (list)
# ┃  ┃    ┣ List item #0 (list)
# ┃  ┃    ┃      ┣ List item #0 (float) : 0.5
# ┃  ┃    ┃      ┣ List item #1 (float) : 0.5
# ┃  ┃    ┃      ┗ List item #2 (float) : 0.5
# ┃  ┃    ┗ List item #1 (list)
# ┃  ┃    ┃      ┣ List item #0 (float) : 0.5
# ┃  ┃    ┃      ┣ List item #1 (float) : 0.5
# ┃  ┃    ┃      ┗ List item #2 (float) : 0.5
# ┃  ┣ umax (list)
# ┃  ┃    ┣ List item #0 (float) : 1.12
# ┃  ┃    ┣ List item #1 (float) : 1.12
# ┃  ┃    ┗ List item #2 (float) : 1.12
# ┃  ┣ cchla (list)
# ┃  ┃    ┣ List item #0 (float) : 181.477
# ┃  ┃    ┣ List item #1 (float) : 181.477
# ┃  ┃    ┗ List item #2 (float) : 181.477
# ┃  ┣ alpha (list)
# ┃  ┃    ┣ List item #0 (float) : 3.96e-16
# ┃  ┃    ┣ List item #1 (float) : 3.96e-16
# ┃  ┃    ┗ List item #2 (float) : 3.96e-16
# ┃  ┣ beta (list)
# ┃  ┃    ┣ List item #0 (float) : 1.1e-18
# ┃  ┃    ┣ List item #1 (float) : 1.1e-18
# ┃  ┃    ┗ List item #2 (float) : 1.1e-18
# ┃  ┣ respg (list)
# ┃  ┃    ┣ List item #0 (float) : 0.1
# ┃  ┃    ┣ List item #1 (float) : 0.1
# ┃  ┃    ┗ List item #2 (float) : 0.1
# ┃  ┣ respb (list)
# ┃  ┃    ┣ List item #0 (float) : 0.02
# ┃  ┃    ┣ List item #1 (float) : 0.02
# ┃  ┃    ┗ List item #2 (float) : 0.02
# ┃  ┣ qminn (list)
# ┃  ┃    ┣ List item #0 (float) : 1.53e-10
# ┃  ┃    ┣ List item #1 (float) : 1.53e-10
# ┃  ┃    ┗ List item #2 (float) : 1.53e-10
# ┃  ┣ qminp (list)
# ┃  ┃    ┣ List item #0 (float) : 1.07e-11
# ┃  ┃    ┣ List item #1 (float) : 1.07e-11
# ┃  ┃    ┗ List item #2 (float) : 1.07e-11
# ┃  ┣ qmaxn (list)
# ┃  ┃    ┣ List item #0 (float) : 6.85e-09
# ┃  ┃    ┣ List item #1 (float) : 6.85e-09
# ┃  ┃    ┗ List item #2 (float) : 6.85e-09
# ┃  ┣ qmaxp (list)
# ┃  ┃    ┣ List item #0 (float) : 4.28e-10
# ┃  ┃    ┣ List item #1 (float) : 4.28e-10
# ┃  ┃    ┗ List item #2 (float) : 4.28e-10
# ┃  ┣ kn (list)
# ┃  ┃    ┣ List item #0 (float) : 1.13
# ┃  ┃    ┣ List item #1 (float) : 1.13
# ┃  ┃    ┗ List item #2 (float) : 1.13
# ┃  ┣ kp (list)
# ┃  ┃    ┣ List item #0 (float) : 0.51
# ┃  ┃    ┣ List item #1 (float) : 0.51
# ┃  ┃    ┗ List item #2 (float) : 0.51
# ┃  ┣ ksi (list)
# ┃  ┃    ┣ List item #0 (float) : 1.13
# ┃  ┃    ┣ List item #1 (float) : 1.13
# ┃  ┃    ┗ List item #2 (float) : 1.13
# ┃  ┣ kqn (list)
# ┃  ┃    ┣ List item #0 (int) : 5
# ┃  ┃    ┣ List item #1 (int) : 5
# ┃  ┃    ┗ List item #2 (int) : 5
# ┃  ┣ kqp (list)
# ┃  ┃    ┣ List item #0 (float) : 0.2
# ┃  ┃    ┣ List item #1 (float) : 0.2
# ┃  ┃    ┗ List item #2 (float) : 0.2
# ┃  ┣ nfqs (list)
# ┃  ┃    ┣ List item #0 (int) : 1
# ┃  ┃    ┣ List item #1 (int) : 1
# ┃  ┃    ┗ List item #2 (int) : 1
# ┃  ┣ vmaxn (list)
# ┃  ┃    ┣ List item #0 (float) : 1.33e-09
# ┃  ┃    ┣ List item #1 (float) : 1.33e-09
# ┃  ┃    ┗ List item #2 (float) : 1.33e-09
# ┃  ┣ vmaxp (list)
# ┃  ┃    ┣ List item #0 (float) : 4.07e-10
# ┃  ┃    ┣ List item #1 (float) : 4.07e-10
# ┃  ┃    ┗ List item #2 (float) : 4.07e-10
# ┃  ┣ vmaxsi (list)
# ┃  ┃    ┣ List item #0 (float) : 1.33e-09
# ┃  ┃    ┣ List item #1 (float) : 1.33e-09
# ┃  ┃    ┗ List item #2 (float) : 1.33e-09
# ┃  ┣ an (list)
# ┃  ┃    ┣ List item #0 (int) : 1
# ┃  ┃    ┣ List item #1 (int) : 1
# ┃  ┃    ┗ List item #2 (int) : 1
# ┃  ┣ volcell (list)
# ┃  ┃    ┣ List item #0 (int) : 513
# ┃  ┃    ┣ List item #1 (int) : 513
# ┃  ┃    ┗ List item #2 (int) : 513
# ┃  ┣ qc (list)
# ┃  ┃    ┣ List item #0 (float) : 4.54e-08
# ┃  ┃    ┣ List item #1 (float) : 4.54e-08
# ┃  ┃    ┗ List item #2 (float) : 4.54e-08
# ┃  ┣ athresh (list)
# ┃  ┃    ┣ List item #0 (float) : 70000000.0
# ┃  ┃    ┣ List item #1 (float) : 70000000.0
# ┃  ┃    ┗ List item #2 (float) : 70000000.0
# ┃  ┣ sinka (list)
# ┃  ┃    ┣ List item #0 (float) : 0.29
# ┃  ┃    ┣ List item #1 (float) : 0.29
# ┃  ┃    ┗ List item #2 (float) : 0.29
# ┃  ┣ ma (list)
# ┃  ┃    ┣ List item #0 (float) : 0.11
# ┃  ┃    ┣ List item #1 (float) : 0.11
# ┃  ┃    ┗ List item #2 (float) : 0.11
# ┃  ┣ a_wt (list)
# ┃  ┃    ┣ List item #0 (int) : 1
# ┃  ┃    ┣ List item #1 (int) : 1
# ┃  ┃    ┗ List item #2 (int) : 1
# ┃  ┗ _start_index (dict)
# ┃  ┃    ┗ ediblevector (list)
# ┃  ┃    ┃      ┣ List item #0 (NoneType) : None
# ┃  ┃    ┃      ┗ List item #1 (int) : 1
# ┣ zooplankton (OrderedDict)
# ┃  ┣ zeffic (list)
# ┃  ┃    ┣ List item #0 (float) : 0.4
# ┃  ┃    ┗ List item #1 (float) : 0.4
# ┃  ┣ zslop (list)
# ┃  ┃    ┣ List item #0 (float) : 0.25
# ┃  ┃    ┗ List item #1 (int) : 0
# ┃  ┣ zvolcell (list)
# ┃  ┃    ┣ List item #0 (float) : 29800000.0
# ┃  ┃    ┗ List item #1 (float) : 674000.0
# ┃  ┣ zqc (list)
# ┃  ┃    ┣ List item #0 (float) : 0.000313
# ┃  ┃    ┗ List item #1 (float) : 7.08e-07
# ┃  ┣ zqn (list)
# ┃  ┃    ┣ List item #0 (float) : 6.95e-05
# ┃  ┃    ┗ List item #1 (float) : 1.57e-07
# ┃  ┣ zqp (list)
# ┃  ┃    ┣ List item #0 (float) : 3.77e-06
# ┃  ┃    ┗ List item #1 (float) : 8.53e-09
# ┃  ┣ zka (list)
# ┃  ┃    ┣ List item #0 (float) : 1120000000000.0
# ┃  ┃    ┗ List item #1 (float) : 1120000000000.0
# ┃  ┣ zrespg (list)
# ┃  ┃    ┣ List item #0 (float) : 0.2
# ┃  ┃    ┗ List item #1 (float) : 0.3
# ┃  ┣ zrespb (list)
# ┃  ┃    ┣ List item #0 (float) : 0.1
# ┃  ┃    ┗ List item #1 (float) : 0.416
# ┃  ┣ zumax (list)
# ┃  ┃    ┣ List item #0 (float) : 945000000.0
# ┃  ┃    ┗ List item #1 (float) : 29800000.0
# ┃  ┗ zm (list)
# ┃  ┃    ┣ List item #0 (float) : 0.00072
# ┃  ┃    ┗ List item #1 (float) : 0.00072
# ┗ om (OrderedDict)
# ┃  ┣ kg1 (int) : 30
# ┃  ┣ kg2 (int) : 30
# ┃  ┣ kg1_r (int) : 11
# ┃  ┣ kg2_r (float) : 3.7
# ┃  ┣ kg1_bc (int) : 1
# ┃  ┣ kg2_bc (int) : 1
# ┃  ┣ knh4 (int) : 1
# ┃  ┣ nitmax (float) : 0.52
# ┃  ┣ ko2 (int) : 10
# ┃  ┣ kstaro2 (int) : 10
# ┃  ┣ kno3 (int) : 5
# ┃  ┣ pco2 (int) : 380
# ┃  ┣ stoich_x1r (int) : 51
# ┃  ┣ stoich_y1r (float) : 4.5
# ┃  ┣ stoich_x2r (int) : 700
# ┃  ┣ stoich_y2r (int) : 50
# ┃  ┣ stoich_x1bc (int) : 106
# ┃  ┣ stoich_y1bc (int) : 16
# ┃  ┣ stoich_x2bc (int) : 106
# ┃  ┣ stoich_y2bc (int) : 16
# ┃  ┣ sinkom1_a (int) : 10
# ┃  ┣ sinkom2_a (int) : 0
# ┃  ┣ sinkom1_z (int) : 10
# ┃  ┣ sinkom2_z (int) : 0
# ┃  ┣ sinkom1_r (int) : 10
# ┃  ┣ sinkom2_r (int) : 0
# ┃  ┣ sinkom1_bc (int) : 0
# ┃  ┣ kgcdom (float) : 0.01
# ┃  ┣ cf_spm (float) : 0.018
# ┃  ┗ kg_bot (int) : 92000
